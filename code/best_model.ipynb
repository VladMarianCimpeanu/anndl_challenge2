# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import keras.backend as K
import random

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import classification_report, confusion_matrix

tfk = tf.keras
tfkl = tfk.layers
seed = 100
plt.style.use('ggplot')

# %% [markdown]
# ## Load data
# Load augmented data (sliding window). Data are already scaled with robust scaler.

# %%
X = np.load(f'/kaggle/input/augmented-challenge2/X_stride1.npy')
y = np.load(f'/kaggle/input/augmented-challenge2/y_stride1.npy')

X.shape
# Out:
# (87024, 36, 6)

# %% [markdown]
# ## Compute weights for classes

# %%
counter = np.bincount(y)
frequencies = 1 / counter
weights = frequencies * (y.shape[0] / frequencies.shape[0])

w_s = {}
for i, w in enumerate(weights):
    w_s[i] = w
w_s
# Out:
# {0: 6.099243061396131,
#  1: 1.6508081038015026,
#  2: 0.7487867836861125,
#  3: 0.5300782106571157,
#  4: 3.300864815657715,
#  5: 1.3250502466654486,
#  6: 0.6455977922193537,
#  7: 3.0053874844591792,
#  8: 1.6924154025670946,
#  9: 0.2595840641443247,
#  10: 2.649616368286445,
#  11: 4.026651860077735}

# %%
1 / frequencies
# Out:
# array([ 1189.,  4393.,  9685., 13681.,  2197.,  5473., 11233.,  2413.,
#         4285., 27937.,  2737.,  1801.])

# %%
def evaluate_model(m, X_val, y_val):
    """
    This method computes the confusion matrix and recall, precision and f1-score for each class.
    :param m: model to evaluate.
    :param X_val: samples to use for the evaluation. X_val cannot be a tf.Dataset object.
    :param y_val: labels for each element of X_val. y_val cannot be a tf.Dataset object.
    :return pandas.DataFrame containing the confusion matrix and pandas.Dataframe whose rows 
    are recall,precision, f1-score and support, whereas columns are the labels.
    """
    y_pred = m.predict(X_val)
    y_pred = tf.argmax(y_pred, axis=1)
    y_true = tf.argmax(y_val, axis=1)
    
    c_m = pd.DataFrame(confusion_matrix(y_true, y_pred, normalize='true'))
    report = classification_report(y_true, y_pred, output_dict=True, zero_division=0)
    report = pd.DataFrame(report)
    report = report.drop(['accuracy', 'macro avg', 'weighted avg'], axis=1)
    
    return c_m, report

# %% [markdown]
# ## Split data
# loaded data use sliding window with stride 1, this means there are multiple samples sharing the same subset of timestamps. Samples sharing the same subset of timestamp must stay in the same set, otherwise we overfit the validation set and we vanish the help given by the validation set.

# %%
df = pd.DataFrame({'y': y})
starting_indexes = list(df.drop_duplicates(keep='first').index.values)
ending_indexes = starting_indexes[1:] + [df.index.values[-1] + 1]

X_train = None
X_val = None

y_train = None
y_val = None

train_percentage = 0.85


for label, starting_index, ending_index in zip(range(12), starting_indexes, ending_indexes):
    
    split_index = int(train_percentage * (ending_index - starting_index))
    split_index += starting_index
    assert split_index + 36 > starting_index
    if X_train is None:
        X_train = X[starting_index: split_index, :, :].copy()
        y_train = y[starting_index: split_index].copy()
        
        X_val = X[split_index + 36: ending_index, :, :].copy()
        y_val = y[split_index + 36: ending_index].copy()
    else:
        X_train = np.append(X_train, X[starting_index: split_index, :, :], axis=0)
        y_train = np.append(y_train, y[starting_index: split_index])
        
        X_val = np.append(X_val, X[split_index + 36: ending_index, :, :], axis=0)
        y_val = np.append(y_val, y[split_index + 36: ending_index])

        
y_train = tfk.utils.to_categorical(y_train)
y_val = tfk.utils.to_categorical(y_val)

print(X_train.shape, X_val.shape, y_train.shape, y_val.shape)
# Out:
# (73966, 36, 6) (12626, 36, 6) (73966, 12) (12626, 12)

# %% [markdown]
# ## Analyze effect of GaussianDropout vs GaussianNoise.
# Using Gaussian dropout, we multply the input by a Noise drawn from $\mathcal{N}(1, \sigma)$, where:
#
# $\sigma = \sqrt{\frac{x}{1 - x}}$.

# %%
plt.title('$\sigma$ for Gaussian dropout')

plt.plot(np.arange(0.01,0.99, 0.1), np.sqrt(np.arange(0.01,0.99, 0.1) / (1 - np.arange(0.01,0.99, 0.1))))
plt.xlabel('$x$')
plt.ylabel('$\sigma$', rotation=0)
plt.show()

# %%
x = tfkl.GaussianDropout(0.4)

# %%
plt.plot([i for i in range(X_train.shape[1])], X_train[0, :, 0], label='normal')
plt.plot([i for i in range(X_train.shape[1])], x(X_train[0, :, 0], training=True), label='dirty')
plt.legend()
plt.show()
# Out:
# 2022-12-13 17:32:36.701215: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:36.791972: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:36.792792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:36.794973: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-13 17:32:36.795439: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:36.796327: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:36.797501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:39.047671: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:39.048591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:39.049297: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-13 17:32:39.049886: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
x = tfkl.GaussianNoise(4)

plt.plot([i for i in range(X_train.shape[1])], X_train[0, :, 0], label='normal')
plt.plot([i for i in range(X_train.shape[1])], x(X_train[0, :, 0], training=True), label='dirty')
plt.legend()
plt.show()

# %%
epochs = 300
batch_size = 512
lr = 1e-3

e_s = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    mode='max',
    restore_best_weights=True,
    patience=40
)

r_LR = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    factor=0.1,
    patience=15,
    mode='max',
    verbose=1,
    min_lr=1e-5
)


callbacks = [e_s, r_LR]

# %%
def build_model(input_shape, n_classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')
    
    # Feature extractor
    convs = []
    
    for _ in range(input_shape[-1]):
        x = tfkl.Conv1D(128,3,padding='same',activation='relu')(input_layer)
        x = tfkl.MaxPooling1D()(x)
        x = tfkl.Conv1D(128,3,padding='same',activation='relu')(x)
        convs.append(x)
        
    x = tfkl.Concatenate()(convs)
    x = tfkl.GlobalAveragePooling1D()(x)
    x = tfkl.Dropout(.2, seed=seed)(x)
    
    
    x = tfkl.Dense(128, activation='relu')(x)
    # Classifier
    output_layer = tfkl.Dense(n_classes, activation='softmax')(x)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')
    
    # Return the model
    return model

# %%
model = build_model(X_train.shape[1:], 12)

categorical_loss = tfk.losses.CategoricalCrossentropy()

model.compile(loss=categorical_loss, optimizer=tfk.optimizers.Adam(learning_rate=lr), metrics='accuracy')

history = model.fit(
    x=X_train,
    y=y_train,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_data=(X_val, y_val),
    shuffle=True,
    class_weight=w_s,
    workers=4,
    use_multiprocessing=True,
)
# Out:
# Epoch 1/300
# 145/145 [==============================] - 4s 23ms/step - loss: 2.3878 - accuracy: 0.2428 - val_loss: 2.3848 - val_accuracy: 0.3338
# Epoch 2/300
# 145/145 [==============================] - 3s 20ms/step - loss: 1.5169 - accuracy: 0.3756 - val_loss: 2.1455 - val_accuracy: 0.3698
# Epoch 3/300
# 145/145 [==============================] - 3s 20ms/step - loss: 1.2048 - accuracy: 0.4469 - val_loss: 1.7513 - val_accuracy: 0.4145
# Epoch 4/300
# 145/145 [==============================] - 3s 20ms/step - loss: 1.0852 - accuracy: 0.4748 - val_loss: 2.1509 - val_accuracy: 0.4426
# Epoch 5/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.9821 - accuracy: 0.5060 - val_loss: 1.8944 - val_accuracy: 0.5058
# Epoch 6/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.8735 - accuracy: 0.5423 - val_loss: 1.9665 - val_accuracy: 0.5002
# Epoch 7/300
# 145/145 [==============================] - 3s 20ms/step - loss: 1.0404 - accuracy: 0.5218 - val_loss: 1.8902 - val_accuracy: 0.4850
# Epoch 8/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.8498 - accuracy: 0.5488 - val_loss: 2.0798 - val_accuracy: 0.5175
# Epoch 9/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.9146 - accuracy: 0.5580 - val_loss: 2.2962 - val_accuracy: 0.4622
# Epoch 10/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.7152 - accuracy: 0.6071 - val_loss: 2.0860 - val_accuracy: 0.5209
# Epoch 11/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.6440 - accuracy: 0.6398 - val_loss: 2.3135 - val_accuracy: 0.5654
# Epoch 12/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.6050 - accuracy: 0.6601 - val_loss: 2.0483 - val_accuracy: 0.5748
# Epoch 13/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.6250 - accuracy: 0.6610 - val_loss: 1.9120 - val_accuracy: 0.4879
# Epoch 14/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.6528 - accuracy: 0.6504 - val_loss: 2.3114 - val_accuracy: 0.6088
# Epoch 15/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.5167 - accuracy: 0.7040 - val_loss: 2.5243 - val_accuracy: 0.6038
# Epoch 16/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.4514 - accuracy: 0.7379 - val_loss: 2.2338 - val_accuracy: 0.6228
# Epoch 17/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.4106 - accuracy: 0.7547 - val_loss: 2.7324 - val_accuracy: 0.6739
# Epoch 18/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.4002 - accuracy: 0.7657 - val_loss: 2.4051 - val_accuracy: 0.6379
# Epoch 19/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.3556 - accuracy: 0.7866 - val_loss: 2.6725 - val_accuracy: 0.6414
# Epoch 20/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.3281 - accuracy: 0.8011 - val_loss: 2.4207 - val_accuracy: 0.6579
# Epoch 21/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.2970 - accuracy: 0.8177 - val_loss: 2.7486 - val_accuracy: 0.6981
# Epoch 22/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.2892 - accuracy: 0.8265 - val_loss: 2.9801 - val_accuracy: 0.6819
# Epoch 23/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.2409 - accuracy: 0.8502 - val_loss: 2.3848 - val_accuracy: 0.6954
# Epoch 24/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.2467 - accuracy: 0.8557 - val_loss: 3.0262 - val_accuracy: 0.6299
# Epoch 25/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.8357 - accuracy: 0.6892 - val_loss: 2.7029 - val_accuracy: 0.6617
# Epoch 26/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.2898 - accuracy: 0.8228 - val_loss: 2.9214 - val_accuracy: 0.6779
# Epoch 27/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.2275 - accuracy: 0.8567 - val_loss: 2.6494 - val_accuracy: 0.6939
# Epoch 28/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.1934 - accuracy: 0.8746 - val_loss: 3.6331 - val_accuracy: 0.6916
# Epoch 29/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.2076 - accuracy: 0.8746 - val_loss: 2.9558 - val_accuracy: 0.6984
# Epoch 30/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1641 - accuracy: 0.8931 - val_loss: 3.3877 - val_accuracy: 0.6891
# Epoch 31/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1435 - accuracy: 0.9051 - val_loss: 2.8660 - val_accuracy: 0.7074
# Epoch 32/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1702 - accuracy: 0.9079 - val_loss: 2.4609 - val_accuracy: 0.7141
# Epoch 33/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1576 - accuracy: 0.9037 - val_loss: 2.7852 - val_accuracy: 0.6984
# Epoch 34/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1211 - accuracy: 0.9220 - val_loss: 2.7069 - val_accuracy: 0.7164
# Epoch 35/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.2106 - accuracy: 0.9060 - val_loss: 2.9017 - val_accuracy: 0.7122
# Epoch 36/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1381 - accuracy: 0.9149 - val_loss: 3.0577 - val_accuracy: 0.7089
# Epoch 37/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1090 - accuracy: 0.9300 - val_loss: 3.2058 - val_accuracy: 0.7149
# Epoch 38/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1139 - accuracy: 0.9328 - val_loss: 3.6547 - val_accuracy: 0.6955
# Epoch 39/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1493 - accuracy: 0.9150 - val_loss: 3.2503 - val_accuracy: 0.7111
# Epoch 40/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1078 - accuracy: 0.9336 - val_loss: 3.5689 - val_accuracy: 0.7007
# Epoch 41/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0966 - accuracy: 0.9419 - val_loss: 3.6088 - val_accuracy: 0.7230
# Epoch 42/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0739 - accuracy: 0.9526 - val_loss: 3.5625 - val_accuracy: 0.7283
# Epoch 43/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0660 - accuracy: 0.9559 - val_loss: 3.5845 - val_accuracy: 0.7239
# Epoch 44/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0574 - accuracy: 0.9623 - val_loss: 3.7822 - val_accuracy: 0.7131
# Epoch 45/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0527 - accuracy: 0.9664 - val_loss: 3.5835 - val_accuracy: 0.7163
# Epoch 46/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0492 - accuracy: 0.9676 - val_loss: 4.1431 - val_accuracy: 0.7224
# Epoch 47/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0540 - accuracy: 0.9678 - val_loss: 4.1191 - val_accuracy: 0.7182
# Epoch 48/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0478 - accuracy: 0.9703 - val_loss: 3.6808 - val_accuracy: 0.7211
# Epoch 49/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0390 - accuracy: 0.9755 - val_loss: 4.0956 - val_accuracy: 0.7246
# Epoch 50/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1240 - accuracy: 0.9452 - val_loss: 6.0757 - val_accuracy: 0.6614
# Epoch 51/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.7062 - accuracy: 0.7973 - val_loss: 3.5681 - val_accuracy: 0.6778
# Epoch 52/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.1220 - accuracy: 0.9272 - val_loss: 4.0591 - val_accuracy: 0.6988
# Epoch 53/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0729 - accuracy: 0.9537 - val_loss: 4.3042 - val_accuracy: 0.7029
# Epoch 54/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0654 - accuracy: 0.9609 - val_loss: 3.8798 - val_accuracy: 0.7266
# Epoch 55/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0733 - accuracy: 0.9619 - val_loss: 3.4536 - val_accuracy: 0.7198
# Epoch 56/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.1023 - accuracy: 0.9455 - val_loss: 3.6934 - val_accuracy: 0.7214
# Epoch 57/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0514 - accuracy: 0.9676 - val_loss: 3.3275 - val_accuracy: 0.7223
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 58/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0399 - accuracy: 0.9753 - val_loss: 3.5635 - val_accuracy: 0.7298
# Epoch 59/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0379 - accuracy: 0.9764 - val_loss: 3.7420 - val_accuracy: 0.7269
# Epoch 60/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0376 - accuracy: 0.9762 - val_loss: 3.6940 - val_accuracy: 0.7294
# Epoch 61/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0370 - accuracy: 0.9769 - val_loss: 3.6526 - val_accuracy: 0.7304
# Epoch 62/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0347 - accuracy: 0.9779 - val_loss: 3.6181 - val_accuracy: 0.7314
# Epoch 63/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0347 - accuracy: 0.9787 - val_loss: 3.6941 - val_accuracy: 0.7298
# Epoch 64/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0326 - accuracy: 0.9795 - val_loss: 3.7379 - val_accuracy: 0.7318
# Epoch 65/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0329 - accuracy: 0.9791 - val_loss: 3.7630 - val_accuracy: 0.7336
# Epoch 66/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0315 - accuracy: 0.9805 - val_loss: 3.6746 - val_accuracy: 0.7291
# Epoch 67/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0311 - accuracy: 0.9802 - val_loss: 3.7593 - val_accuracy: 0.7304
# Epoch 68/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0303 - accuracy: 0.9814 - val_loss: 3.8150 - val_accuracy: 0.7325
# Epoch 69/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0308 - accuracy: 0.9808 - val_loss: 3.9528 - val_accuracy: 0.7327
# Epoch 70/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0297 - accuracy: 0.9815 - val_loss: 3.9884 - val_accuracy: 0.7358
# Epoch 71/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0300 - accuracy: 0.9816 - val_loss: 4.1579 - val_accuracy: 0.7294
# Epoch 72/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0283 - accuracy: 0.9815 - val_loss: 4.0055 - val_accuracy: 0.7343
# Epoch 73/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0280 - accuracy: 0.9828 - val_loss: 4.0499 - val_accuracy: 0.7323
# Epoch 74/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0277 - accuracy: 0.9830 - val_loss: 4.1310 - val_accuracy: 0.7351
# Epoch 75/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0270 - accuracy: 0.9834 - val_loss: 4.2415 - val_accuracy: 0.7306
# Epoch 76/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0267 - accuracy: 0.9839 - val_loss: 4.2747 - val_accuracy: 0.7328
# Epoch 77/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0255 - accuracy: 0.9839 - val_loss: 4.2494 - val_accuracy: 0.7339
# Epoch 78/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0249 - accuracy: 0.9852 - val_loss: 4.2686 - val_accuracy: 0.7341
# Epoch 79/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0244 - accuracy: 0.9853 - val_loss: 4.1794 - val_accuracy: 0.7366
# Epoch 80/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0234 - accuracy: 0.9860 - val_loss: 4.2783 - val_accuracy: 0.7380
# Epoch 81/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0237 - accuracy: 0.9859 - val_loss: 4.2488 - val_accuracy: 0.7365
# Epoch 82/300
# 145/145 [==============================] - 3s 22ms/step - loss: 0.0225 - accuracy: 0.9866 - val_loss: 4.2440 - val_accuracy: 0.7385
# Epoch 83/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0223 - accuracy: 0.9865 - val_loss: 4.4116 - val_accuracy: 0.7331
# Epoch 84/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0218 - accuracy: 0.9869 - val_loss: 4.4184 - val_accuracy: 0.7318
# Epoch 85/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0216 - accuracy: 0.9869 - val_loss: 4.2812 - val_accuracy: 0.7359
# Epoch 86/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0214 - accuracy: 0.9875 - val_loss: 4.9171 - val_accuracy: 0.7358
# Epoch 87/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0202 - accuracy: 0.9878 - val_loss: 4.4617 - val_accuracy: 0.7328
# Epoch 88/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0203 - accuracy: 0.9878 - val_loss: 4.4810 - val_accuracy: 0.7306
# Epoch 89/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0198 - accuracy: 0.9881 - val_loss: 4.3704 - val_accuracy: 0.7348
# Epoch 90/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0191 - accuracy: 0.9889 - val_loss: 4.4434 - val_accuracy: 0.7370
# Epoch 91/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0189 - accuracy: 0.9888 - val_loss: 4.6110 - val_accuracy: 0.7388
# Epoch 92/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0179 - accuracy: 0.9890 - val_loss: 4.4338 - val_accuracy: 0.7395
# Epoch 93/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0183 - accuracy: 0.9898 - val_loss: 4.5310 - val_accuracy: 0.7335
# Epoch 94/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0181 - accuracy: 0.9890 - val_loss: 4.4046 - val_accuracy: 0.7400
# Epoch 95/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0174 - accuracy: 0.9894 - val_loss: 4.3903 - val_accuracy: 0.7378
# Epoch 96/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0165 - accuracy: 0.9902 - val_loss: 4.6003 - val_accuracy: 0.7392
# Epoch 97/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0164 - accuracy: 0.9905 - val_loss: 4.3249 - val_accuracy: 0.7411
# Epoch 98/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0159 - accuracy: 0.9908 - val_loss: 4.2218 - val_accuracy: 0.7383
# Epoch 99/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0155 - accuracy: 0.9908 - val_loss: 4.4236 - val_accuracy: 0.7387
# Epoch 100/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0157 - accuracy: 0.9916 - val_loss: 4.4540 - val_accuracy: 0.7380
# Epoch 101/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0153 - accuracy: 0.9915 - val_loss: 4.5021 - val_accuracy: 0.7403
# Epoch 102/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0146 - accuracy: 0.9916 - val_loss: 4.6095 - val_accuracy: 0.7405
# Epoch 103/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0141 - accuracy: 0.9916 - val_loss: 5.4306 - val_accuracy: 0.7380
# Epoch 104/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0144 - accuracy: 0.9915 - val_loss: 4.5602 - val_accuracy: 0.7393
# Epoch 105/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0140 - accuracy: 0.9916 - val_loss: 4.7483 - val_accuracy: 0.7358
# Epoch 106/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0135 - accuracy: 0.9921 - val_loss: 4.6933 - val_accuracy: 0.7392
# Epoch 107/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0131 - accuracy: 0.9924 - val_loss: 4.6905 - val_accuracy: 0.7355
# Epoch 108/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0130 - accuracy: 0.9925 - val_loss: 4.5233 - val_accuracy: 0.7396
# Epoch 109/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0131 - accuracy: 0.9925 - val_loss: 4.6263 - val_accuracy: 0.7399
# Epoch 110/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0129 - accuracy: 0.9930 - val_loss: 4.6128 - val_accuracy: 0.7396
# Epoch 111/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0125 - accuracy: 0.9930 - val_loss: 5.0211 - val_accuracy: 0.7377
# Epoch 112/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0112 - accuracy: 0.9937 - val_loss: 4.9892 - val_accuracy: 0.7406
#
# Epoch 00112: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 113/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0109 - accuracy: 0.9941 - val_loss: 4.9347 - val_accuracy: 0.7393
# Epoch 114/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0112 - accuracy: 0.9940 - val_loss: 4.9451 - val_accuracy: 0.7393
# Epoch 115/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0110 - accuracy: 0.9940 - val_loss: 4.9289 - val_accuracy: 0.7400
# Epoch 116/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0109 - accuracy: 0.9938 - val_loss: 4.9627 - val_accuracy: 0.7407
# Epoch 117/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0113 - accuracy: 0.9940 - val_loss: 4.8879 - val_accuracy: 0.7409
# Epoch 118/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0110 - accuracy: 0.9938 - val_loss: 4.8497 - val_accuracy: 0.7415
# Epoch 119/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0109 - accuracy: 0.9938 - val_loss: 4.8433 - val_accuracy: 0.7405
# Epoch 120/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0109 - accuracy: 0.9940 - val_loss: 4.8470 - val_accuracy: 0.7414
# Epoch 121/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0107 - accuracy: 0.9938 - val_loss: 4.8379 - val_accuracy: 0.7429
# Epoch 122/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0106 - accuracy: 0.9946 - val_loss: 4.8787 - val_accuracy: 0.7429
# Epoch 123/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0107 - accuracy: 0.9943 - val_loss: 4.8895 - val_accuracy: 0.7414
# Epoch 124/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0107 - accuracy: 0.9945 - val_loss: 4.9056 - val_accuracy: 0.7406
# Epoch 125/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0105 - accuracy: 0.9939 - val_loss: 4.8562 - val_accuracy: 0.7416
# Epoch 126/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0106 - accuracy: 0.9942 - val_loss: 4.8994 - val_accuracy: 0.7413
# Epoch 127/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0105 - accuracy: 0.9943 - val_loss: 4.8719 - val_accuracy: 0.7414
# Epoch 128/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0104 - accuracy: 0.9944 - val_loss: 4.8755 - val_accuracy: 0.7415
# Epoch 129/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0104 - accuracy: 0.9943 - val_loss: 4.8688 - val_accuracy: 0.7412
# Epoch 130/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0105 - accuracy: 0.9942 - val_loss: 4.8591 - val_accuracy: 0.7415
# Epoch 131/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0104 - accuracy: 0.9946 - val_loss: 4.8741 - val_accuracy: 0.7404
# Epoch 132/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0101 - accuracy: 0.9943 - val_loss: 4.8857 - val_accuracy: 0.7409
# Epoch 133/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0104 - accuracy: 0.9943 - val_loss: 4.9282 - val_accuracy: 0.7405
# Epoch 134/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0100 - accuracy: 0.9946 - val_loss: 4.9243 - val_accuracy: 0.7416
# Epoch 135/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0102 - accuracy: 0.9942 - val_loss: 4.8987 - val_accuracy: 0.7427
# Epoch 136/300
# 145/145 [==============================] - 3s 22ms/step - loss: 0.0101 - accuracy: 0.9942 - val_loss: 4.8807 - val_accuracy: 0.7412
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 1e-05.
# Epoch 137/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0094 - accuracy: 0.9950 - val_loss: 4.8630 - val_accuracy: 0.7416
# Epoch 138/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0102 - accuracy: 0.9944 - val_loss: 4.8921 - val_accuracy: 0.7415
# Epoch 139/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0098 - accuracy: 0.9948 - val_loss: 4.9363 - val_accuracy: 0.7416
# Epoch 140/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0100 - accuracy: 0.9946 - val_loss: 4.9090 - val_accuracy: 0.7412
# Epoch 141/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0098 - accuracy: 0.9946 - val_loss: 4.8832 - val_accuracy: 0.7415
# Epoch 142/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0100 - accuracy: 0.9947 - val_loss: 4.9129 - val_accuracy: 0.7408
# Epoch 143/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0099 - accuracy: 0.9946 - val_loss: 4.9336 - val_accuracy: 0.7428
# Epoch 144/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0100 - accuracy: 0.9943 - val_loss: 4.8888 - val_accuracy: 0.7426
# Epoch 145/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0100 - accuracy: 0.9947 - val_loss: 4.8499 - val_accuracy: 0.7424
# Epoch 146/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0096 - accuracy: 0.9946 - val_loss: 4.8901 - val_accuracy: 0.7420
# Epoch 147/300
# 145/145 [==============================] - 3s 21ms/step - loss: 0.0101 - accuracy: 0.9944 - val_loss: 4.9184 - val_accuracy: 0.7401
# Epoch 148/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0094 - accuracy: 0.9945 - val_loss: 4.9219 - val_accuracy: 0.7412
# Epoch 149/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0100 - accuracy: 0.9949 - val_loss: 4.9243 - val_accuracy: 0.7409
# Epoch 150/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0093 - accuracy: 0.9949 - val_loss: 4.8758 - val_accuracy: 0.7412
# Epoch 151/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0096 - accuracy: 0.9946 - val_loss: 4.8697 - val_accuracy: 0.7412
# Epoch 152/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0092 - accuracy: 0.9953 - val_loss: 4.8987 - val_accuracy: 0.7414
# Epoch 153/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0094 - accuracy: 0.9945 - val_loss: 4.9014 - val_accuracy: 0.7407
# Epoch 154/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0096 - accuracy: 0.9946 - val_loss: 4.8534 - val_accuracy: 0.7404
# Epoch 155/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0094 - accuracy: 0.9949 - val_loss: 4.8594 - val_accuracy: 0.7416
# Epoch 156/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0099 - accuracy: 0.9945 - val_loss: 4.8351 - val_accuracy: 0.7383
# Epoch 157/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0096 - accuracy: 0.9945 - val_loss: 4.8001 - val_accuracy: 0.7416
# Epoch 158/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0095 - accuracy: 0.9948 - val_loss: 4.8018 - val_accuracy: 0.7416
# Epoch 159/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0093 - accuracy: 0.9946 - val_loss: 4.8155 - val_accuracy: 0.7424
# Epoch 160/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0091 - accuracy: 0.9952 - val_loss: 4.8079 - val_accuracy: 0.7411
# Epoch 161/300
# 145/145 [==============================] - 3s 20ms/step - loss: 0.0091 - accuracy: 0.9955 - val_loss: 4.8483 - val_accuracy: 0.7401

# %%
print(np.max(history.history['val_accuracy']))
print(np.max(history.history['accuracy']))
x_axis = np.arange(len(history.history['val_accuracy']))

plt.figure(figsize=(12, 6))
plt.title("Accuracy")
plt.plot(x_axis, history.history["accuracy"], label="train accuracy")
plt.plot(x_axis, history.history["val_accuracy"], label="validation accuracy")


plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()
# Out:
# 0.7429114580154419
# 0.9954979419708252

# %%
c_m, report = evaluate_model(model, X_val, y_val)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(c_m, cmap='Blues', annot=True)
plt.show()

# %%
report
# Out:
#                     0           1            2            3           4  \
# precision    0.629921    0.714286     0.961931     0.603853    0.518919
# recall       0.559441    0.617978     0.998589     0.497273    0.326531
# f1-score     0.592593    0.662651     0.979917     0.545405    0.400835
# support    143.000000  623.000000  1417.000000  2017.000000  294.000000
#
#                     5            6           7           8            9  \
# precision    0.492723     0.877388    0.686047    0.922953     0.699766
# recall       0.301911     0.863554    0.361963    0.947282     0.864982
# f1-score     0.374408     0.870416    0.473896    0.934959     0.773652
# support    785.000000  1649.000000  326.000000  607.000000  4155.000000
#
#                    10          11
# precision    0.997085    0.418868
# recall       0.912000    0.472340
# f1-score     0.952646    0.444000
# support    375.000000  235.000000

# %%
model.save('models/')
